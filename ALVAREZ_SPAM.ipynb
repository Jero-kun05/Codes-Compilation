# %%
#Import all essential libraries.

import pandas as pd 
import numpy as np 
import tensorflow as tf  
import matplotlib.pyplot as plt

#Import additional libraries needed for creating neural network.

from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
#Preparing the data for representation and adding labels.

dataset = pd.read_csv('spam.csv',encoding='latin-1')
dataset = dataset.drop(["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"], axis=1)
dataset = dataset.rename(columns={"v1":'Type', "v2":'Content'})

tags = dataset["Type"]
texts = dataset["Content"]

dataset['Type'].unique()
label = {'spam': 1,'ham': 0}
dataset['Type'].replace(label, inplace=True)

# %%
#Preparing the data to be trained.
#Training the text and tag data.

training_size = int(len(texts) * 0.8)

training_texts = texts[0:training_size]
testing_texts = texts[training_size:]

training_tags = tags[0:training_size]
testing_tags = tags[training_size:]

training_tags_final = np.array(training_tags)
testing_tags_final = np.array(testing_tags)

# %%
#Tokenize the dataset

vocab_size = 1000
embedding_dim = 16
max_length = 100

trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"

tokenizer = Tokenizer(num_words = vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(training_texts)
word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(training_texts)
padded = pad_sequences(sequences,maxlen=max_length, padding=padding_type, 
                       truncating=trunc_type)

testing_sequences = tokenizer.texts_to_sequences(testing_texts)
testing_padded = pad_sequences(testing_sequences,maxlen=max_length, 
                               padding=padding_type, truncating=trunc_type)

# %%
#Creatibg the Model for the data

model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(6, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

#Present the table of model data

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 100, 16)           16000
#
#  flatten (Flatten)           (None, 1600)              0
#
#  dense (Dense)               (None, 6)                 9606
#
#  dense_1 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 25,613
# Trainable params: 25,613
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Using the epoch funtion to train the data.

num_epochs = 50
history=model.fit(padded, training_tags_final, epochs=num_epochs, validation_data=(testing_padded, testing_tags_final))
# Out:
# Epoch 1/50
# 140/140 [==============================] - 1s 4ms/step - loss: 5.4273e-04 - accuracy: 0.9998 - val_loss: 0.1767 - val_accuracy: 0.9767
# Epoch 2/50
# 140/140 [==============================] - 0s 3ms/step - loss: 5.7431e-04 - accuracy: 0.9996 - val_loss: 0.1821 - val_accuracy: 0.9740
# Epoch 3/50
# 140/140 [==============================] - 0s 3ms/step - loss: 5.6413e-04 - accuracy: 0.9996 - val_loss: 0.1800 - val_accuracy: 0.9776
# Epoch 4/50
# 140/140 [==============================] - 0s 3ms/step - loss: 6.1365e-04 - accuracy: 0.9996 - val_loss: 0.1875 - val_accuracy: 0.9740
# Epoch 5/50
# 140/140 [==============================] - 1s 5ms/step - loss: 5.4907e-04 - accuracy: 0.9996 - val_loss: 0.1796 - val_accuracy: 0.9758
# Epoch 6/50
# 140/140 [==============================] - 1s 4ms/step - loss: 4.7865e-04 - accuracy: 0.9998 - val_loss: 0.1880 - val_accuracy: 0.9758
# Epoch 7/50
# 140/140 [==============================] - 1s 4ms/step - loss: 5.1683e-04 - accuracy: 0.9998 - val_loss: 0.1894 - val_accuracy: 0.9731
# Epoch 8/50
# 140/140 [==============================] - 1s 4ms/step - loss: 4.7316e-04 - accuracy: 0.9998 - val_loss: 0.1907 - val_accuracy: 0.9749
# Epoch 9/50
# 140/140 [==============================] - 1s 4ms/step - loss: 3.9050e-04 - accuracy: 0.9998 - val_loss: 0.1866 - val_accuracy: 0.9776
# Epoch 10/50
# 140/140 [==============================] - 1s 4ms/step - loss: 4.8386e-04 - accuracy: 0.9998 - val_loss: 0.1859 - val_accuracy: 0.9758
# Epoch 11/50
# 140/140 [==============================] - 1s 4ms/step - loss: 5.2292e-04 - accuracy: 0.9996 - val_loss: 0.1867 - val_accuracy: 0.9758
# Epoch 12/50
# 140/140 [==============================] - 1s 4ms/step - loss: 4.8264e-04 - accuracy: 0.9998 - val_loss: 0.1899 - val_accuracy: 0.9758
# Epoch 13/50
# 140/140 [==============================] - 1s 4ms/step - loss: 4.9158e-04 - accuracy: 0.9998 - val_loss: 0.1916 - val_accuracy: 0.9767
# Epoch 14/50
# 140/140 [==============================] - 1s 4ms/step - loss: 4.9090e-04 - accuracy: 0.9998 - val_loss: 0.1934 - val_accuracy: 0.9767
# Epoch 15/50
# 140/140 [==============================] - 0s 3ms/step - loss: 4.7997e-04 - accuracy: 0.9998 - val_loss: 0.1901 - val_accuracy: 0.9758
# Epoch 16/50
# 140/140 [==============================] - 0s 3ms/step - loss: 5.5976e-04 - accuracy: 0.9996 - val_loss: 0.1893 - val_accuracy: 0.9776
# Epoch 17/50
# 140/140 [==============================] - 0s 3ms/step - loss: 6.7945e-04 - accuracy: 0.9996 - val_loss: 0.1903 - val_accuracy: 0.9758
# Epoch 18/50
# 140/140 [==============================] - 0s 3ms/step - loss: 5.8774e-04 - accuracy: 0.9996 - val_loss: 0.1905 - val_accuracy: 0.9767
# Epoch 19/50
# 140/140 [==============================] - 0s 3ms/step - loss: 4.3122e-04 - accuracy: 0.9998 - val_loss: 0.1938 - val_accuracy: 0.9776
# Epoch 20/50
# 140/140 [==============================] - 0s 3ms/step - loss: 5.0662e-04 - accuracy: 0.9998 - val_loss: 0.1951 - val_accuracy: 0.9749
# Epoch 21/50
# 140/140 [==============================] - 0s 3ms/step - loss: 4.5736e-04 - accuracy: 0.9998 - val_loss: 0.1997 - val_accuracy: 0.9758
# Epoch 22/50
# 140/140 [==============================] - 0s 3ms/step - loss: 4.8698e-04 - accuracy: 0.9996 - val_loss: 0.1987 - val_accuracy: 0.9749
# Epoch 23/50
# 140/140 [==============================] - 0s 3ms/step - loss: 4.4076e-04 - accuracy: 0.9996 - val_loss: 0.1991 - val_accuracy: 0.9758
# Epoch 24/50
# 140/140 [==============================] - 1s 4ms/step - loss: 4.6620e-04 - accuracy: 0.9996 - val_loss: 0.1986 - val_accuracy: 0.9776
# Epoch 25/50
# 140/140 [==============================] - 1s 4ms/step - loss: 5.2920e-04 - accuracy: 0.9998 - val_loss: 0.2031 - val_accuracy: 0.9749
# Epoch 26/50
# 140/140 [==============================] - 1s 4ms/step - loss: 5.2537e-04 - accuracy: 0.9996 - val_loss: 0.1939 - val_accuracy: 0.9776
# Epoch 27/50
# 140/140 [==============================] - 0s 3ms/step - loss: 4.4937e-04 - accuracy: 0.9996 - val_loss: 0.1965 - val_accuracy: 0.9749
# Epoch 28/50
# 140/140 [==============================] - 0s 3ms/step - loss: 4.7651e-04 - accuracy: 0.9996 - val_loss: 0.1990 - val_accuracy: 0.9767
# Epoch 29/50
# 140/140 [==============================] - 0s 3ms/step - loss: 4.6159e-04 - accuracy: 0.9998 - val_loss: 0.2043 - val_accuracy: 0.9767
# Epoch 30/50
# 140/140 [==============================] - 0s 3ms/step - loss: 4.6712e-04 - accuracy: 0.9998 - val_loss: 0.1984 - val_accuracy: 0.9749
# Epoch 31/50
# 140/140 [==============================] - 0s 4ms/step - loss: 4.2251e-04 - accuracy: 0.9998 - val_loss: 0.2050 - val_accuracy: 0.9758
# Epoch 32/50
# 140/140 [==============================] - 0s 3ms/step - loss: 4.7473e-04 - accuracy: 0.9996 - val_loss: 0.2065 - val_accuracy: 0.9767
# Epoch 33/50
# 140/140 [==============================] - 0s 3ms/step - loss: 4.7072e-04 - accuracy: 0.9998 - val_loss: 0.1998 - val_accuracy: 0.9749
# Epoch 34/50
# 140/140 [==============================] - 0s 3ms/step - loss: 5.3513e-04 - accuracy: 0.9996 - val_loss: 0.2078 - val_accuracy: 0.9749
# Epoch 35/50
# 140/140 [==============================] - 0s 3ms/step - loss: 5.9230e-04 - accuracy: 0.9996 - val_loss: 0.1986 - val_accuracy: 0.9767
# Epoch 36/50
# 140/140 [==============================] - 0s 3ms/step - loss: 4.7881e-04 - accuracy: 0.9998 - val_loss: 0.2053 - val_accuracy: 0.9767
# Epoch 37/50
# 140/140 [==============================] - 0s 4ms/step - loss: 5.6710e-04 - accuracy: 0.9998 - val_loss: 0.2117 - val_accuracy: 0.9749
# Epoch 38/50
# 140/140 [==============================] - 1s 4ms/step - loss: 3.8429e-04 - accuracy: 0.9996 - val_loss: 0.2125 - val_accuracy: 0.9749
# Epoch 39/50
# 140/140 [==============================] - 1s 4ms/step - loss: 4.1531e-04 - accuracy: 0.9996 - val_loss: 0.2096 - val_accuracy: 0.9749
# Epoch 40/50
# 140/140 [==============================] - 1s 4ms/step - loss: 4.5364e-04 - accuracy: 0.9998 - val_loss: 0.2148 - val_accuracy: 0.9767
# Epoch 41/50
# 140/140 [==============================] - 1s 4ms/step - loss: 4.6641e-04 - accuracy: 0.9998 - val_loss: 0.2112 - val_accuracy: 0.9767
# Epoch 42/50
# 140/140 [==============================] - 1s 4ms/step - loss: 4.4282e-04 - accuracy: 0.9998 - val_loss: 0.2084 - val_accuracy: 0.9749
# Epoch 43/50
# 140/140 [==============================] - 1s 4ms/step - loss: 4.1558e-04 - accuracy: 0.9996 - val_loss: 0.2159 - val_accuracy: 0.9776
# Epoch 44/50
# 140/140 [==============================] - 1s 4ms/step - loss: 5.1155e-04 - accuracy: 0.9996 - val_loss: 0.2240 - val_accuracy: 0.9776
# Epoch 45/50
# 140/140 [==============================] - 0s 3ms/step - loss: 4.9451e-04 - accuracy: 0.9996 - val_loss: 0.2099 - val_accuracy: 0.9776
# Epoch 46/50
# 140/140 [==============================] - 1s 4ms/step - loss: 5.0309e-04 - accuracy: 0.9998 - val_loss: 0.2211 - val_accuracy: 0.9749
# Epoch 47/50
# 140/140 [==============================] - 0s 3ms/step - loss: 5.4154e-04 - accuracy: 0.9996 - val_loss: 0.2077 - val_accuracy: 0.9767
# Epoch 48/50
# 140/140 [==============================] - 0s 3ms/step - loss: 5.0707e-04 - accuracy: 0.9998 - val_loss: 0.2248 - val_accuracy: 0.9794
# Epoch 49/50
# 140/140 [==============================] - 0s 3ms/step - loss: 7.0668e-04 - accuracy: 0.9998 - val_loss: 0.2283 - val_accuracy: 0.9749
# Epoch 50/50
# 140/140 [==============================] - 0s 3ms/step - loss: 4.7262e-04 - accuracy: 0.9998 - val_loss: 0.2283 - val_accuracy: 0.9758

# %%
#Listing all the data history.

print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
#Recalling and determining the accuracy of the program.

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')

# %%
#Presenting the data.

dataset = pd.read_csv('output_spam.csv',encoding='latin-1')
dataset = dataset.rename(columns={"ï»¿":'labels', "text":'texts'})
dataset.head()
# Out:
#    labels                                              texts
# 0       1  Feel Yourself That You Are Always Happy.. Slow...
# 1       2  staff.science.nus.edu.sg/~phyhcmk/teaching/pc1323
# 2       3                        Send me yetty's number pls.
# 3       4  Hey so this sat are we going for the intro pil...
# 4       5  I got it before the new year cos yetunde said ...

# %%
#Displaying messages.

messages = dataset['texts'].astype(str)
print(messages)

#Ming of sequences.

padding_type='post'
sample_sequences = tokenizer.texts_to_sequences(messages)
fakes_padded = pad_sequences(sample_sequences, padding=padding_type, maxlen=max_length)           

classes = model.predict(fakes_padded)
# Out:
# 0     Feel Yourself That You Are Always Happy.. Slow...
# 1     staff.science.nus.edu.sg/~phyhcmk/teaching/pc1323
# 2                           Send me yetty's number pls.
# 3     Hey so this sat are we going for the intro pil...
# 4     I got it before the new year cos yetunde said ...
# 5     Hey we can go jazz power yoga hip hop kb and y...
# 6     Hey mate. Spoke to the mag people. Weâ°ÃÃ·re...
# 7                                Morning only i can ok.
# 8                                  Wat time Ã_ finish?
# 9                 Shant disturb u anymore... Jia you...
# 10    4mths half price Orange line rental & latest c...
# 11    Your opinion about me? 1. Over 2. Jada 3. Kusr...
# 12    MOON has come to color your dreams, STARS to m...
# 13    You are a winner U have been specially selecte...
# 14    Unless it's a situation where YOU GO GURL woul...
# 15    Awww dat is sweet! We can think of something t...
# 16                              Bring tat cd don forget
# 17    Single line with a big meaning::::: \Miss anyt...
# 18       Jay's getting really impatient and belligerent
# 19    Lol they were mad at first but then they woke ...
# Name: texts, dtype: object
# 1/1 [==============================] - 0s 32ms/step

# %%
#Classification of spam messages in the data.

for x in range(len(messages)):
  print(messages[x])
  print(classes[x])
  print('\n')
# Out:
# Feel Yourself That You Are Always Happy.. Slowly It Becomes Your Habit &amp; Finally It Becomes Part Of Your Life.. Follow It.. Happy Morning &amp; Have A Happy Day:)
# [1.9495945e-23]
#
#
# staff.science.nus.edu.sg/~phyhcmk/teaching/pc1323
# [6.164149e-08]
#
#
# Send me yetty's number pls.
# [2.6905875e-11]
#
#
# Hey so this sat are we going for the intro pilates only? Or the kickboxing too?
# [1.9410972e-12]
#
#
# I got it before the new year cos yetunde said she wanted to surprise you with it but when i didnt see money i returned it mid january before the  &lt;#&gt; day return period ended.
# [1.5009595e-16]
#
#
# Hey we can go jazz power yoga hip hop kb and yogasana
# [1.8413131e-12]
#
#
# Hey mate. Spoke to the mag people. Weâ°ÃÃ·re on.  the is deliver by the end of the month. Deliver on the 24th sept. Talk later.
# [1.8874266e-14]
#
#
# Morning only i can ok.
# [1.4585403e-14]
#
#
# Wat time Ã_ finish?
# [2.8013756e-09]
#
#
# Shant disturb u anymore... Jia you...
# [2.3601965e-09]
#
#
# 4mths half price Orange line rental & latest camera phones 4 FREE. Had your phone 11mths ? Call MobilesDirect free on 08000938767 to update now! or2stoptxt
# [1.]
#
#
# Your opinion about me? 1. Over 2. Jada 3. Kusruthi 4. Lovable 5. Silent 6. Spl character 7. Not matured 8. Stylish 9. Simple Pls reply..
# [3.1804973e-08]
#
#
# MOON has come to color your dreams, STARS to make them musical and my SMS to give you warm and Peaceful Sleep. Good Night
# [3.782858e-09]
#
#
# You are a winner U have been specially selected 2 receive Ã¥Â£1000 cash or a 4* holiday (flights inc) speak to a live operator 2 claim 0871277810810
# [1.]
#
#
# Unless it's a situation where YOU GO GURL would be more appropriate
# [1.9825171e-13]
#
#
# Awww dat is sweet! We can think of something to do he he! Have a nice time tonight ill probably txt u later cos im lonely :( xxx.
# [6.902522e-26]
#
#
# Bring tat cd don forget
# [4.6519943e-07]
#
#
# Single line with a big meaning::::: \Miss anything 4 ur \"Best Life\" but
# [3.048338e-09]
#
#
# Jay's getting really impatient and belligerent
# [1.4127693e-06]
#
#
# Lol they were mad at first but then they woke up and gave in.
# [4.974048e-09]
